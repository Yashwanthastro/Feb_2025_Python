# %%
import os 
os.getcwd()
# get Current working directory(cwd)
# Out:
# 'C:\\Users\\User\\Documents\\nareshit\\Python_Sessions'

# %% [markdown]
# ## Variables

# %% [markdown]
# Variables are used to store the values, and the values can be change

# %%
num=100
# value 100 stored in a variable called:num
print(num)
# Out:
# 100

# %%
num=200
print(num)
# Out:
# 200

# %%
NUM=200
NUM
# Out:
# 200

# %%
number=300
number
# Out:
# 300

# %%
number,NUM
# Out:
# (300, 200)

# %%
num123=300
num123
# Out:
# 300

# %%
123number=400
123number
# Out:
#   File "<ipython-input-10-47f85ce15b30>", line 1
#     123number=400
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# NUMBERone=500
# NUMBERone

# %%
number&one=600
number&one
# Out:
#   File "<ipython-input-12-c5ae3d67ad2e>", line 1
#     number&one=600
#     ^
# SyntaxError: cannot assign to operator

# %%
number_one=600
number_one
# Out:
# 600

# %%
number one=350
number one
# Out:
#   File "<ipython-input-14-369825b7e9d4>", line 1
#     number one=350
#            ^
# SyntaxError: invalid syntax

# %%
NUM # works
number # works
num123 # works
123num # not works
number$one # NW
number&one # NW
number_one # work
number one # NW
if=100 # NW
_=100 # works

# %% [markdown]
# - variables can be a capital letters
# - variables can be a small letter
# - variable can be mix of both capital and small letters
# - variables can be mix of letters and numbers as **suffix**
# - variables can not be a mix of letters and numbers as **perfix**
# - variables can not be include special chars except **underscore**
# - variable can not be include a **space between words**
# - only underscore is consider as variables
# - inbuilt keywords can not be a variables

# %%
_=600
_
# Out:
# 600
